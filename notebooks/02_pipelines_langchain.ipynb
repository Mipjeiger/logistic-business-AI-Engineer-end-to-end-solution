# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
def load_data(file_path):
    df = pd.read_csv(file_path)
    return df

pd.set_option('display.max_columns', None)
df = load_data('../data/supply_chain_data_expanded.csv')

# %%
df.head()
# Out:
#                                Order_id  Availability       Costs  \
# 0  6af613b6-569c-5c22-9c37-2ed93f31d3af            55  188.684667
# 1  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39            55  187.492481
# 2  4b166dbe-d99d-5091-abdd-95b83330ed3a            55  188.968124
# 3  98123fde-012f-5ff3-8b50-881449dac91a            55  190.611596
# 4  6ed955c6-506a-5343-9be4-2c0afae02eef            55  187.312448
#
#   Customer demographics  Defect rates Inspection results  Lead time  \
# 0            Non-binary      0.224447            Pending         29
# 1            Non-binary      0.226086            Pending         29
# 2            Non-binary      0.231951            Pending         29
# 3            Non-binary      0.233616            Pending         29
# 4            Non-binary      0.221073            Pending         29
#
#    Lead times Location  Manufacturing costs  Manufacturing lead time  \
# 0           8   Mumbai            43.469393                       29
# 1           8   Mumbai            51.332779                       29
# 2           9   Mumbai            47.134300                       29
# 3           8   Mumbai            53.945541                       29
# 4           8   Mumbai            40.762402                       29
#
#    Number of products sold  Order quantities      Price Product type  \
# 0                      802                98  71.933529     haircare
# 1                      802                95  70.933955     haircare
# 2                      802                98  72.899584     haircare
# 3                      802                98  65.259225     haircare
# 4                      802                95  77.743599     haircare
#
#    Production volumes  Revenue generated   Routes Shipping carriers  \
# 0                 214        8763.759148  Route B         Carrier B
# 1                 213        8499.239523  Route B         Carrier B
# 2                 213        8633.603195  Route B         Carrier B
# 3                 213        8658.388203  Route B         Carrier B
# 4                 216        8663.374800  Route B         Carrier B
#
#    Shipping costs  Shipping times  Stock levels Supplier name  \
# 0        2.601292               6            59    Supplier 3
# 1        3.220109               3            58    Supplier 3
# 2        3.257622               2            57    Supplier 3
# 3        3.040814               6            59    Supplier 3
# 4        2.703847               3            57    Supplier 3
#
#   Transportation modes
# 0                 Road
# 1                 Road
# 2                 Road
# 3                 Road
# 4                 Road

# %%
df.columns.tolist()
# Out:
# ['Order_id',
#  'Availability',
#  'Costs',
#  'Customer demographics',
#  'Defect rates',
#  'Inspection results',
#  'Lead time',
#  'Lead times',
#  'Location',
#  'Manufacturing costs',
#  'Manufacturing lead time',
#  'Number of products sold',
#  'Order quantities',
#  'Price',
#  'Product type',
#  'Production volumes',
#  'Revenue generated',
#  'Routes',
#  'Shipping carriers',
#  'Shipping costs',
#  'Shipping times',
#  'Stock levels',
#  'Supplier name',
#  'Transportation modes']
