# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import psycopg2
warnings.filterwarnings('ignore')

from sqlalchemy import create_engine
from dotenv import load_dotenv

# %% [markdown]
# ## Load SQL Dataset

# %%
# Load data from sql
def load_data(query: str) -> pd.DataFrame:
    # Load environment variables from .env file
    env_path = os.path.join("..", ".env")
    load_dotenv(dotenv_path=env_path)

    # Retrieve database connection parameters
    DB_USER = os.getenv("DB_USER")
    DB_PASSWORD = os.getenv("DB_PASSWORD")
    DB_HOST = os.getenv("DB_HOST")
    DB_PORT = os.getenv("DB_PORT")
    DB_NAME = os.getenv("DB_NAME")

    # Use psycopg2 directly
    conn = psycopg2.connect(
        host=DB_HOST,
        port=DB_PORT,
        database=DB_NAME,
        user=DB_USER,
        password=DB_PASSWORD
    )
    
    try:
        df = pd.read_sql_query(query, conn)
        return df
    finally:
        conn.close()

# %%
# List of SQL Queries

query_1 = "SELECT * FROM raw.supply_chain_data;"
query_2 = "SELECT * FROM core.products;"
query_3 = "SELECT * FROM core.suppliers;"
query_4 = "SELECT * FROM core.inventory_status;"
query_5 = "SELECT * FROM core.sales_orders;"
query_6 = "SELECT * FROM core.production_metrics;"
query_7 = "SELECT * FROM staging.stg_supply_chain_data;"
query_8 = "SELECT * FROM logistics.shipments;"
query_9 = "SELECT * FROM inspection.quality_inspections;"
query_10 = "SELECT * FROM logistics.container_registry;"
query_11 = "SELECT * FROM logistics.shipments;"
query_12 = "SELECT * FROM inspection.feature_mart;"
query_13 = "SELECT * FROM inspection.cv_detections;"
query_14 = "SELECT * FROM ml.inspection_training;"
query_15 = "SELECT * FROM ml.inspection_training m LEFT JOIN logistics.shipments s ON m.shipment_id = s.shipment_id;"

# %%
for sql in [query_1, query_2, query_3, query_4, query_5, query_6, query_7, query_8, query_9, query_10, query_11, query_12, query_13, query_14]:
    df = load_data(sql)
    print(f"Data from query:\n{df.head()}\n")
# Out:
# Data from query:
#                                order_id  availability     costs  \
# 0  6af613b6-569c-5c22-9c37-2ed93f31d3af            55  188.6847
# 1  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39            55  187.4925
# 2  4b166dbe-d99d-5091-abdd-95b83330ed3a            55  188.9681
# 3  98123fde-012f-5ff3-8b50-881449dac91a            55  190.6116
# 4  6ed955c6-506a-5343-9be4-2c0afae02eef            55  187.3124
#
#   customer_demographics  defect_rates inspection_results  lead_time  \
# 0            Non-binary      0.224447            Pending         29
# 1            Non-binary      0.226086            Pending         29
# 2            Non-binary      0.231951            Pending         29
# 3            Non-binary      0.233616            Pending         29
# 4            Non-binary      0.221073            Pending         29
#
#    lead_times location  manufacturing_costs  ...  product_type  \
# 0           8   Mumbai              43.4694  ...      haircare
# 1           8   Mumbai              51.3328  ...      haircare
# 2           9   Mumbai              47.1343  ...      haircare
# 3           8   Mumbai              53.9455  ...      haircare
# 4           8   Mumbai              40.7624  ...      haircare
#
#    production_volumes  revenue_generated   routes shipping_carriers  \
# 0                 214          8763.7591  Route B         Carrier B
# 1                 213          8499.2395  Route B         Carrier B
# 2                 213          8633.6032  Route B         Carrier B
# 3                 213          8658.3882  Route B         Carrier B
# 4                 216          8663.3748  Route B         Carrier B
#
#    shipping_costs  shipping_times stock_levels supplier_name  \
# 0          2.6013               6           59    Supplier 3
# 1          3.2201               3           58    Supplier 3
# 2          3.2576               2           57    Supplier 3
# 3          3.0408               6           59    Supplier 3
# 4          2.7038               3           57    Supplier 3
#
#    transportation_modes
# 0                  Road
# 1                  Road
# 2                  Road
# 3                  Road
# 4                  Road
#
# [5 rows x 24 columns]
#
# Data from query:
#                              product_id product_type  price  \
# 0  3c46f06b-2cf6-57f6-ab77-a95f5572071c     haircare  75.56
# 1  f0ac696f-bfa5-568d-9f2c-9efb539dd5e0     haircare  25.70
# 2  7aad5c85-6e57-54ec-8ac8-c677bf8e6572     skincare   4.02
# 3  bebf428c-b5b7-5336-8b72-26dbbbea698c    cosmetics  83.82
# 4  12b6c108-b2a2-5036-a9d2-5a5dd543fd29    cosmetics   6.49
#
#                   created_at
# 0 2026-01-29 14:09:27.596822
# 1 2026-01-29 14:09:27.596822
# 2 2026-01-29 14:09:27.596822
# 3 2026-01-29 14:09:27.596822
# 4 2026-01-29 14:09:27.596822
#
# Data from query:
#                             supplier_id supplier_name   location
# 0  f0840541-582b-4cd7-8e4b-675d14885b1d    Supplier 4     Mumbai
# 1  308095e9-0367-4155-bdbf-5bd2b8dbdf71    Supplier 1      Delhi
# 2  df282daa-885f-472e-9cfe-60dcc97d9202    Supplier 1  Bangalore
# 3  5e8912a0-2a51-4bda-8181-2ae3b29e5bc6    Supplier 2  Bangalore
# 4  27415fea-7f99-4659-89b0-5ff57dc2ef2b    Supplier 3      Delhi
#
# Data from query:
#                            inventory_id                            product_id  \
# 0  5061c7e9-33cc-419c-9966-f59476acf769  6af613b6-569c-5c22-9c37-2ed93f31d3af
# 1  3afef723-73af-460e-859c-123e109b6088  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 2  5ed2f92c-ab62-4bfb-907e-17453eea55a0  4b166dbe-d99d-5091-abdd-95b83330ed3a
# 3  45ea300a-606c-46a3-8d9a-60cbe4c58754  98123fde-012f-5ff3-8b50-881449dac91a
# 4  cb3a5feb-ca89-4a52-a21c-e172852a6cff  6ed955c6-506a-5343-9be4-2c0afae02eef
#
#    stock_levels  availability recorded_at
# 0            59            55  2026-01-29
# 1            58            55  2026-01-29
# 2            57            55  2026-01-29
# 3            59            55  2026-01-29
# 4            57            55  2026-01-29
#
# Data from query:
#                                sales_id                            product_id  \
# 0  3b11c58b-7663-4d0a-a7d7-48e56902391c  6af613b6-569c-5c22-9c37-2ed93f31d3af
# 1  b4f6f6d5-76b4-4a8f-80b4-77ecbc149955  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 2  d0e1992f-75e6-4c8b-bccb-fdcb02ff0466  4b166dbe-d99d-5091-abdd-95b83330ed3a
# 3  105597a4-433a-4fce-b681-085c5a410bbb  98123fde-012f-5ff3-8b50-881449dac91a
# 4  e14d6e5d-7efe-47c7-9bee-f670e1f0fbce  6ed955c6-506a-5343-9be4-2c0afae02eef
#
#    products_sold  revenue_generated  order_date
# 0            802            8763.76  2026-01-29
# 1            802            8499.24  2026-01-29
# 2            802            8633.60  2026-01-29
# 3            802            8658.39  2026-01-29
# 4            802            8663.37  2026-01-29
#
# Data from query:
#                           production_id                            product_id  \
# 0  27292394-788f-4253-9cc4-4d1b3ef5c6e0  6af613b6-569c-5c22-9c37-2ed93f31d3af
# 1  dccbe68b-4274-467d-a9bd-df79fef6d089  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 2  37917324-dcc4-41eb-bab5-abbb418bf2fe  4b166dbe-d99d-5091-abdd-95b83330ed3a
# 3  174bca68-aaa0-48ab-9ccd-b9ab60a397be  98123fde-012f-5ff3-8b50-881449dac91a
# 4  5a12b7be-3f05-44e5-a47f-998922b915f1  6ed955c6-506a-5343-9be4-2c0afae02eef
#
#    production_volumes  manufacturing_cost  manufacturing_lead_time recorded_at
# 0                 214               43.47                       29  2026-01-29
# 1                 213               51.33                       29  2026-01-29
# 2                 213               47.13                       29  2026-01-29
# 3                 213               53.95                       29  2026-01-29
# 4                 216               40.76                       29  2026-01-29
#
# Data from query:
#                                order_id  availability     costs  \
# 0  6af613b6-569c-5c22-9c37-2ed93f31d3af            55  188.6847
# 1  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39            55  187.4925
# 2  4b166dbe-d99d-5091-abdd-95b83330ed3a            55  188.9681
# 3  98123fde-012f-5ff3-8b50-881449dac91a            55  190.6116
# 4  6ed955c6-506a-5343-9be4-2c0afae02eef            55  187.3124
#
#   customer_demographics  defect_rates inspection_results  lead_time  \
# 0            Non-binary      0.224447            Pending         29
# 1            Non-binary      0.226086            Pending         29
# 2            Non-binary      0.231951            Pending         29
# 3            Non-binary      0.233616            Pending         29
# 4            Non-binary      0.221073            Pending         29
#
#    lead_times location  manufacturing_costs  ...  product_type  \
# 0           8   Mumbai              43.4694  ...      haircare
# 1           8   Mumbai              51.3328  ...      haircare
# 2           9   Mumbai              47.1343  ...      haircare
# 3           8   Mumbai              53.9455  ...      haircare
# 4           8   Mumbai              40.7624  ...      haircare
#
#    production_volumes  revenue_generated   routes shipping_carriers  \
# 0                 214          8763.7591  Route B         Carrier B
# 1                 213          8499.2395  Route B         Carrier B
# 2                 213          8633.6032  Route B         Carrier B
# 3                 213          8658.3882  Route B         Carrier B
# 4                 216          8663.3748  Route B         Carrier B
#
#    shipping_costs  shipping_times stock_levels supplier_name  \
# 0          2.6013               6           59    Supplier 3
# 1          3.2201               3           58    Supplier 3
# 2          3.2576               2           57    Supplier 3
# 3          3.0408               6           59    Supplier 3
# 4          2.7038               3           57    Supplier 3
#
#    transportation_modes
# 0                  Road
# 1                  Road
# 2                  Road
# 3                  Road
# 4                  Road
#
# [5 rows x 24 columns]
#
# Data from query:
#                             shipment_id                            product_id  \
# 0  00008f68-92bf-4a78-ae7d-fbd7777e6118  571c764d-3494-590e-a92a-3d1fae982307
# 1  000134e7-0c94-48f5-ad2e-a65802791497  75c17c44-28e4-5394-924e-1fe88480eef4
# 2  0002802a-34be-440d-9830-b929cf450699  8b2cc05f-a1ad-5f3d-a3bf-3302b5cc9adb
# 3  0008b8e3-5204-45ea-9ebb-962288fd1e24  6799c474-653d-559d-8638-c8e45c7e6c2e
# 4  000b13e6-df05-48df-a32e-32ef2b7668c6  6fcc2a1b-dc88-50a5-bb99-da1c9fe6f75a
#
#                             supplier_id shipping_carrier transportation_mode  \
# 0  481d2a47-1926-4300-a761-3eaee832726e        Carrier B                Road
# 1  5851b929-d1da-42ae-8e9a-03fb1a00dc5e        Carrier C                 Sea
# 2  78f7bced-cc7f-42ca-97ca-454196333805        Carrier A                Rail
# 3  78f7bced-cc7f-42ca-97ca-454196333805        Carrier B                Rail
# 4  f0840541-582b-4cd7-8e4b-675d14885b1d        Carrier A                Road
#
#      route  shipping_cost  total_cost  shipping_time  shipped_at
# 0  Route B           4.39      849.65              5  2026-01-24
# 1  Route B           8.12      760.83             10  2026-01-24
# 2  Route B           7.42      996.64              2  2026-01-24
# 3  Route B           4.35      230.18             10  2026-01-24
# 4  Route C           4.79      472.60              1  2026-01-24
#
# Data from query:
#                           inspection_id                            product_id  \
# 0  c0a687cd-aad6-438c-acc5-87affaeb4ee9  6af613b6-569c-5c22-9c37-2ed93f31d3af
# 1  86cd4fa5-983c-4338-8f94-0e30a0e6403b  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 2  ca8b347c-2b68-48a8-aabf-663cc25b9862  4b166dbe-d99d-5091-abdd-95b83330ed3a
# 3  78716785-883e-4047-b0f3-e9e56e250c31  98123fde-012f-5ff3-8b50-881449dac91a
# 4  d5f4ef67-a556-47cc-8672-1349f1805754  6ed955c6-506a-5343-9be4-2c0afae02eef
#
#   inspection_result  defect_rate  lead_time inspected_at
# 0           Pending     0.224447         29   2026-01-29
# 1           Pending     0.226086         29   2026-01-29
# 2           Pending     0.231951         29   2026-01-29
# 3           Pending     0.233616         29   2026-01-29
# 4           Pending     0.221073         29   2026-01-29
#
# Data from query:
#                                container_id  \
# 0  CNT-e04414bd-9bd2-461f-9c81-e188b49ac75e
# 1  CNT-d6e550f5-8226-4188-bfde-5d4144744c61
# 2  CNT-f6e056bb-ac2a-4c20-a8a5-26958b4f1b1b
# 3  CNT-bc01ea7f-48f9-42af-8a00-db0adaf2984c
# 4  CNT-25f722cd-f1ce-4048-aef9-22e1110ca5e9
#
#                             shipment_id  \
# 0  53fd9980-513c-467d-aa8a-e445120175fa
# 1  7295f588-e705-4f52-b55f-a2dcd855a34a
# 2  40a1446b-2742-4f4d-98f1-cc19ad9535a8
# 3  4e57bcd8-5300-4324-a10f-008127e3be7f
# 4  4a6c7132-754e-46c9-b123-63d7375a39a5
#
#                                   image_name                captured_at
# 0   111_20220211T041351392Z_s00.mp4_2400.jpg 2026-01-27 07:58:59.000784
# 1   10_20220315T010303302Z_s00.mp4_44600.jpg 2026-01-27 07:58:59.000791
# 2  111_20220422T014816656Z_s00.mp4_14300.jpg 2026-01-27 07:58:59.000794
# 3   104_20220321T021706325Z_s00.mp4_2000.jpg 2026-01-27 07:58:59.000800
# 4    12_20220527T120309238Z_s00.mp4_1100.jpg 2026-01-27 07:58:59.000803
#
# Data from query:
#                             shipment_id                            product_id  \
# 0  00008f68-92bf-4a78-ae7d-fbd7777e6118  571c764d-3494-590e-a92a-3d1fae982307
# 1  000134e7-0c94-48f5-ad2e-a65802791497  75c17c44-28e4-5394-924e-1fe88480eef4
# 2  0002802a-34be-440d-9830-b929cf450699  8b2cc05f-a1ad-5f3d-a3bf-3302b5cc9adb
# 3  0008b8e3-5204-45ea-9ebb-962288fd1e24  6799c474-653d-559d-8638-c8e45c7e6c2e
# 4  000b13e6-df05-48df-a32e-32ef2b7668c6  6fcc2a1b-dc88-50a5-bb99-da1c9fe6f75a
#
#                             supplier_id shipping_carrier transportation_mode  \
# 0  481d2a47-1926-4300-a761-3eaee832726e        Carrier B                Road
# 1  5851b929-d1da-42ae-8e9a-03fb1a00dc5e        Carrier C                 Sea
# 2  78f7bced-cc7f-42ca-97ca-454196333805        Carrier A                Rail
# 3  78f7bced-cc7f-42ca-97ca-454196333805        Carrier B                Rail
# 4  f0840541-582b-4cd7-8e4b-675d14885b1d        Carrier A                Road
#
#      route  shipping_cost  total_cost  shipping_time  shipped_at
# 0  Route B           4.39      849.65              5  2026-01-24
# 1  Route B           8.12      760.83             10  2026-01-24
# 2  Route B           7.42      996.64              2  2026-01-24
# 3  Route B           4.35      230.18             10  2026-01-24
# 4  Route C           4.79      472.60              1  2026-01-24
#
# Data from query:
#                             shipment_id  total_detections  avg_confidence  \
# 0  79bda302-f268-44fb-9809-1f1eac6351c9                 3          0.8390
# 1  7194879c-2956-4e47-bfdf-c39f0e93a1c9                 2          0.7815
# 2  f98b7815-a0ea-48c6-9e76-49f6327640e9                 1          0.8410
# 3  710cad1d-321c-4055-ac33-d55efc2452a9                 2          0.7805
# 4  9df2637f-02cf-444f-b368-455a14e87e13                 4          0.9120
#
#    total_damage_area  dent_count
# 0           0.011429           0
# 1           0.014831           0
# 2           0.003400           0
# 3           0.021901           0
# 4           0.023889           0
#
# Data from query:
#                            detection_id  \
# 0  c14e129b-62fa-48c7-9d7c-98acedb7f1bf
# 1  b73784e2-1036-4d72-9b7c-e3662afbaeb4
# 2  6dd811b3-6437-4d41-b73e-b513de0d3bee
# 3  f4345e22-343c-41ab-9277-bea38daf2001
# 4  5eb3a128-9d3a-4d11-81da-2f806b55d278
#
#                                   image_name  \
# 0  14_20220428T012931844Z_s00.mp4_108400.jpg
# 1  14_20220428T012931844Z_s00.mp4_108400.jpg
# 2  14_20220428T012931844Z_s00.mp4_108400.jpg
# 3  114_20220425T114900821Z_s00.mp4_35100.jpg
# 4  114_20220425T114900821Z_s00.mp4_35100.jpg
#
#                             shipment_id  \
# 0  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 1  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 2  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 3  df75a457-a3f2-42b3-98fb-650fea877b70
# 4  df75a457-a3f2-42b3-98fb-650fea877b70
#
#                                container_id class_id  confidence  \
# 0  CNT-59083db3-904b-4876-992a-3aee14f226d7        0       0.989
# 1  CNT-59083db3-904b-4876-992a-3aee14f226d7        0       0.987
# 2  CNT-59083db3-904b-4876-992a-3aee14f226d7        1       0.876
# 3  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352        0       0.937
# 4  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352        0       0.751
#
#    bbox_x_center  bbox_y_center  bbox_width  bbox_height  bbox_area  \
# 0       0.535185       0.273698    0.035185     0.197396   0.006945
# 1       0.954630       0.268490    0.029630     0.226562   0.006713
# 2       0.145833       0.521875    0.084259     0.022917   0.001931
# 3       0.561111       0.274740    0.053704     0.226562   0.012167
# 4       0.787500       0.351042    0.032407     0.159375   0.005165
#
#                  detected_at model_version
# 0 2026-01-26 18:37:47.802469       yolo_v8
# 1 2026-01-26 18:37:47.802495       yolo_v8
# 2 2026-01-26 18:37:47.802498       yolo_v8
# 3 2026-01-26 18:37:47.802771       yolo_v8
# 4 2026-01-26 18:37:47.802774       yolo_v8
#
# Data from query:
#                             shipment_id  total_detections  avg_confidence  \
# 0  76ca8527-35b6-4b6e-82a5-ac1516853d14                 4          0.8425
# 1  bf046423-d395-4109-8431-e03a6ac08bf5                 2          0.8870
# 2  160ad73a-faa7-4cd5-a68d-7c351a0c30a1                 2          0.8560
# 3  f221fddb-9725-456b-a674-d6c3315328b2                 2          0.8660
# 4  6a5c35a6-8d70-4b53-982e-9ece522a34c2                 3          0.9080
#
#    total_damage_area  dent_count  defect_rate  is_high_risk
# 0           0.011481           0     0.226086             0
# 1           0.012859           0     0.232399             1
# 2           0.005352           0     0.224839             0
# 3           0.010610           0     0.221834             0
# 4           0.008472           0     0.227898             0

# %%
metadata = pd.read_csv("../data/image_metadata.csv")
metadata.head()
# Out:
#    detection_id                                 image_name  \
# 0           NaN  14_20220428T012931844Z_s00.mp4_108400.jpg
# 1           NaN  14_20220428T012931844Z_s00.mp4_108400.jpg
# 2           NaN  14_20220428T012931844Z_s00.mp4_108400.jpg
# 3           NaN  114_20220425T114900821Z_s00.mp4_35100.jpg
# 4           NaN  114_20220425T114900821Z_s00.mp4_35100.jpg
#
#                             shipment_id  \
# 0  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 1  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 2  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 3  df75a457-a3f2-42b3-98fb-650fea877b70
# 4  df75a457-a3f2-42b3-98fb-650fea877b70
#
#                                container_id  class_id  confidence    bbox_x  \
# 0  CNT-59083db3-904b-4876-992a-3aee14f226d7         0       0.989  0.535185
# 1  CNT-59083db3-904b-4876-992a-3aee14f226d7         0       0.987  0.954630
# 2  CNT-59083db3-904b-4876-992a-3aee14f226d7         1       0.876  0.145833
# 3  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352         0       0.937  0.561111
# 4  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352         0       0.751  0.787500
#
#      bbox_y    bbox_w    bbox_h  bbox_area                 detected_at  \
# 0  0.273698  0.035185  0.197396   0.006945  2026-01-26 18:37:47.802469
# 1  0.268490  0.029630  0.226562   0.006713  2026-01-26 18:37:47.802495
# 2  0.521875  0.084259  0.022917   0.001931  2026-01-26 18:37:47.802498
# 3  0.274740  0.053704  0.226562   0.012167  2026-01-26 18:37:47.802771
# 4  0.351042  0.032407  0.159375   0.005165  2026-01-26 18:37:47.802774
#
#   model_version
# 0       yolo_v8
# 1       yolo_v8
# 2       yolo_v8
# 3       yolo_v8
# 4       yolo_v8

# %%
# Primary: SELECT * FROM inspection.cv_detections;
load_data(query_13).head()
# Out:
#                            detection_id  \
# 0  c14e129b-62fa-48c7-9d7c-98acedb7f1bf
# 1  b73784e2-1036-4d72-9b7c-e3662afbaeb4
# 2  6dd811b3-6437-4d41-b73e-b513de0d3bee
# 3  f4345e22-343c-41ab-9277-bea38daf2001
# 4  5eb3a128-9d3a-4d11-81da-2f806b55d278
#
#                                   image_name  \
# 0  14_20220428T012931844Z_s00.mp4_108400.jpg
# 1  14_20220428T012931844Z_s00.mp4_108400.jpg
# 2  14_20220428T012931844Z_s00.mp4_108400.jpg
# 3  114_20220425T114900821Z_s00.mp4_35100.jpg
# 4  114_20220425T114900821Z_s00.mp4_35100.jpg
#
#                             shipment_id  \
# 0  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 1  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 2  2ad1dfa0-0791-4e07-b12c-9f5b268b6f66
# 3  df75a457-a3f2-42b3-98fb-650fea877b70
# 4  df75a457-a3f2-42b3-98fb-650fea877b70
#
#                                container_id class_id  confidence  \
# 0  CNT-59083db3-904b-4876-992a-3aee14f226d7        0       0.989
# 1  CNT-59083db3-904b-4876-992a-3aee14f226d7        0       0.987
# 2  CNT-59083db3-904b-4876-992a-3aee14f226d7        1       0.876
# 3  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352        0       0.937
# 4  CNT-8cebf7ae-ecfd-4484-abce-2a60220a5352        0       0.751
#
#    bbox_x_center  bbox_y_center  bbox_width  bbox_height  bbox_area  \
# 0       0.535185       0.273698    0.035185     0.197396   0.006945
# 1       0.954630       0.268490    0.029630     0.226562   0.006713
# 2       0.145833       0.521875    0.084259     0.022917   0.001931
# 3       0.561111       0.274740    0.053704     0.226562   0.012167
# 4       0.787500       0.351042    0.032407     0.159375   0.005165
#
#                  detected_at model_version
# 0 2026-01-26 18:37:47.802469       yolo_v8
# 1 2026-01-26 18:37:47.802495       yolo_v8
# 2 2026-01-26 18:37:47.802498       yolo_v8
# 3 2026-01-26 18:37:47.802771       yolo_v8
# 4 2026-01-26 18:37:47.802774       yolo_v8

# %%
# manual inspector results: SELECT * FROM inspection.quality_inspections;
load_data(query_9).head()
# Out:
#                           inspection_id                            product_id  \
# 0  c0a687cd-aad6-438c-acc5-87affaeb4ee9  6af613b6-569c-5c22-9c37-2ed93f31d3af
# 1  86cd4fa5-983c-4338-8f94-0e30a0e6403b  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 2  ca8b347c-2b68-48a8-aabf-663cc25b9862  4b166dbe-d99d-5091-abdd-95b83330ed3a
# 3  78716785-883e-4047-b0f3-e9e56e250c31  98123fde-012f-5ff3-8b50-881449dac91a
# 4  d5f4ef67-a556-47cc-8672-1349f1805754  6ed955c6-506a-5343-9be4-2c0afae02eef
#
#   inspection_result  defect_rate  lead_time inspected_at
# 0           Pending     0.224447         29   2026-01-29
# 1           Pending     0.226086         29   2026-01-29
# 2           Pending     0.231951         29   2026-01-29
# 3           Pending     0.233616         29   2026-01-29
# 4           Pending     0.221073         29   2026-01-29

# %%
# Business Impact Layer: SELECT * FROM logistics.shipments;
load_data(query_11).head()
# Out:
#                             shipment_id                            product_id  \
# 0  00008f68-92bf-4a78-ae7d-fbd7777e6118  571c764d-3494-590e-a92a-3d1fae982307
# 1  000134e7-0c94-48f5-ad2e-a65802791497  75c17c44-28e4-5394-924e-1fe88480eef4
# 2  0002802a-34be-440d-9830-b929cf450699  8b2cc05f-a1ad-5f3d-a3bf-3302b5cc9adb
# 3  0008b8e3-5204-45ea-9ebb-962288fd1e24  6799c474-653d-559d-8638-c8e45c7e6c2e
# 4  000b13e6-df05-48df-a32e-32ef2b7668c6  6fcc2a1b-dc88-50a5-bb99-da1c9fe6f75a
#
#                             supplier_id shipping_carrier transportation_mode  \
# 0  481d2a47-1926-4300-a761-3eaee832726e        Carrier B                Road
# 1  5851b929-d1da-42ae-8e9a-03fb1a00dc5e        Carrier C                 Sea
# 2  78f7bced-cc7f-42ca-97ca-454196333805        Carrier A                Rail
# 3  78f7bced-cc7f-42ca-97ca-454196333805        Carrier B                Rail
# 4  f0840541-582b-4cd7-8e4b-675d14885b1d        Carrier A                Road
#
#      route  shipping_cost  total_cost  shipping_time  shipped_at
# 0  Route B           4.39      849.65              5  2026-01-24
# 1  Route B           8.12      760.83             10  2026-01-24
# 2  Route B           7.42      996.64              2  2026-01-24
# 3  Route B           4.35      230.18             10  2026-01-24
# 4  Route C           4.79      472.60              1  2026-01-24

# %%
# ML Layer: SELECT * FROM ml.inspection_training;
load_data(query_14).head()
# Out:
#                             shipment_id  total_detections  avg_confidence  \
# 0  76ca8527-35b6-4b6e-82a5-ac1516853d14                 4          0.8425
# 1  bf046423-d395-4109-8431-e03a6ac08bf5                 2          0.8870
# 2  160ad73a-faa7-4cd5-a68d-7c351a0c30a1                 2          0.8560
# 3  f221fddb-9725-456b-a674-d6c3315328b2                 2          0.8660
# 4  6a5c35a6-8d70-4b53-982e-9ece522a34c2                 3          0.9080
#
#    total_damage_area  dent_count  defect_rate  is_high_risk
# 0           0.011481           0     0.226086             0
# 1           0.012859           0     0.232399             1
# 2           0.005352           0     0.224839             0
# 3           0.010610           0     0.221834             0
# 4           0.008472           0     0.227898             0

# %%
load_data(query_14).head() # SELECT * FROM ml.inspection_training;
# Out:
#                             shipment_id  total_detections  avg_confidence  \
# 0  76ca8527-35b6-4b6e-82a5-ac1516853d14                 4          0.8425
# 1  bf046423-d395-4109-8431-e03a6ac08bf5                 2          0.8870
# 2  160ad73a-faa7-4cd5-a68d-7c351a0c30a1                 2          0.8560
# 3  f221fddb-9725-456b-a674-d6c3315328b2                 2          0.8660
# 4  6a5c35a6-8d70-4b53-982e-9ece522a34c2                 3          0.9080
#
#    total_damage_area  dent_count  defect_rate  is_high_risk
# 0           0.011481           0     0.226086             0
# 1           0.012859           0     0.232399             1
# 2           0.005352           0     0.224839             0
# 3           0.010610           0     0.221834             0
# 4           0.008472           0     0.227898             0

# %%
load_data(query_15).head() # SELECT * FROM ml.inspection_training m LEFT JOIN logistics.shipments s ON m.shipment_id = s.shipment_id;
# Out:
#                             shipment_id  total_detections  avg_confidence  \
# 0  76ca8527-35b6-4b6e-82a5-ac1516853d14                 4          0.8425
# 1  bf046423-d395-4109-8431-e03a6ac08bf5                 2          0.8870
# 2  160ad73a-faa7-4cd5-a68d-7c351a0c30a1                 2          0.8560
# 3  f221fddb-9725-456b-a674-d6c3315328b2                 2          0.8660
# 4  6a5c35a6-8d70-4b53-982e-9ece522a34c2                 3          0.9080
#
#    total_damage_area  dent_count  defect_rate  is_high_risk  \
# 0           0.011481           0     0.226086             0
# 1           0.012859           0     0.232399             1
# 2           0.005352           0     0.224839             0
# 3           0.010610           0     0.221834             0
# 4           0.008472           0     0.227898             0
#
#                             shipment_id                            product_id  \
# 0  76ca8527-35b6-4b6e-82a5-ac1516853d14  b04965e6-a9bb-591f-8f8a-1adcb2c8dc39
# 1  bf046423-d395-4109-8431-e03a6ac08bf5  7fef88f7-411d-5669-b42d-bf5fc7f9b58b
# 2  160ad73a-faa7-4cd5-a68d-7c351a0c30a1  23986425-d3a5-5e13-8bab-299745777a8d
# 3  f221fddb-9725-456b-a674-d6c3315328b2  ce1ae2d5-3454-5952-97ff-36ff935bcfe9
# 4  6a5c35a6-8d70-4b53-982e-9ece522a34c2  8f8173d9-2f8d-5636-a693-24d9f79ba651
#
#                             supplier_id shipping_carrier transportation_mode  \
# 0  a3257930-e46a-4994-ae1c-28e5a794489e        Carrier B                Road
# 1  bccc2020-682a-4478-9518-a1e220548c72        Carrier B                Road
# 2  27415fea-7f99-4659-89b0-5ff57dc2ef2b        Carrier B                Road
# 3  bccc2020-682a-4478-9518-a1e220548c72        Carrier B                Road
# 4  bdf8677d-73aa-408a-b2cd-78caba9743e4        Carrier B                Road
#
#      route  shipping_cost  total_cost  shipping_time  shipped_at
# 0  Route B           3.22      187.49              3  2026-01-24
# 1  Route B           2.71      186.88              2  2026-01-24
# 2  Route B           2.69      186.70              2  2026-01-24
# 3  Route B           2.77      188.46              6  2026-01-24
# 4  Route B           3.31      191.23              2  2026-01-24
